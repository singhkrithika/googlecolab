# %% [markdown]
# #Conscientious Cars 2: Convolutional Neural Nets
#
# Welcome back to CC: ConscientiousCars! Today, we'll be improving on our system for distinguishing dogs from roads, so we can keep these cute puppers safe.

# %%
#@title Run this to load some packages and data! { display-mode: "form" }
from sklearn.neural_network import MLPClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn import model_selection
from sklearn.metrics import accuracy_score
from collections import Counter
import keras
from keras.models import Sequential
from keras.layers import Dense, Conv2D
from keras.layers import Activation, MaxPooling2D, Dropout, Flatten, Reshape
from keras.wrappers.scikit_learn import KerasClassifier
from sklearn.model_selection import StratifiedKFold
from sklearn.model_selection import cross_val_score
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt


def categorical_to_numpy(labels_in):
  labels = []
  for label in labels_in:
    if label == 'dog':
      labels.append(np.array([1, 0]))
    else:
      labels.append(np.array([0, 1]))
  return np.array(labels)


def load_data():
  # Run this cell to download our data into a file called 'cifar_data'
  import gdown
  gdown.download('https://drive.google.com/uc?id=1-BjeqccJdLiBA6PnNinmXSQ6w5BluLem','cifar_data','True'); # dogs v road;

  # now load the data from our cloud computer
  import pickle
  data_dict = pickle.load(open( "cifar_data", "rb" ));
  
  data   = data_dict['data']
  labels = data_dict['labels']
  
  return data, labels

def plot_one_image(data, labels, img_idx):
  from google.colab.patches import cv2_imshow
  import cv2
  import matplotlib.pyplot as plt
  my_img   = data[img_idx, :].squeeze().reshape([32,32,3]).copy()
  my_label = labels[img_idx]
  print('label: %s'%my_label)
  plt.imshow(my_img)
  plt.show()
  
def CNNClassifier(num_epochs=2, layers=1, dropout=0.15):
  def create_model():
    model = Sequential()
    model.add(Reshape((32, 32, 3)))
    
    for i in range(layers):
      model.add(Conv2D(32, (3, 3), padding='same'))
      model.add(Activation('relu'))
    
    model.add(Conv2D(32, (3, 3)))
    model.add(Activation('relu'))
    model.add(MaxPooling2D(pool_size=(2, 2)))
    model.add(Dropout(dropout))

    model.add(Conv2D(64, (3, 3), padding='same'))
    model.add(Activation('relu'))
    model.add(Conv2D(64, (3, 3)))
    model.add(Activation('relu'))
    model.add(MaxPooling2D(pool_size=(2, 2)))
    model.add(Dropout(dropout))

    model.add(Flatten())
    model.add(Dense(512))
    model.add(Activation('relu'))
    model.add(Dropout(dropout))
    model.add(Dense(2))
    model.add(Activation('softmax'))

    # initiate RMSprop optimizer
    opt = keras.optimizers.RMSprop(lr=0.0001, decay=1e-6)

    # Let's train the model using RMSprop
    model.compile(loss='categorical_crossentropy',
                  optimizer=opt,
                  metrics=['accuracy'])
    return model
  return KerasClassifier(build_fn=create_model, epochs=num_epochs, batch_size=10, verbose=2)

def plot_acc(history, ax = None, xlabel = 'Epoch #'):
    history = history.history
    history.update({'epoch':list(range(len(history['val_accuracy'])))})
    history = pd.DataFrame.from_dict(history)

    best_epoch = history.sort_values(by = 'val_accuracy', ascending = False).iloc[0]['epoch']

    if not ax:
      f, ax = plt.subplots(1,1)
    sns.lineplot(x = 'epoch', y = 'val_accuracy', data = history, label = 'Validation', ax = ax)
    sns.lineplot(x = 'epoch', y = 'accuracy', data = history, label = 'Training', ax = ax)
    ax.axhline(0.5, linestyle = '--',color='red', label = 'Chance')
    ax.axvline(x = best_epoch, linestyle = '--', color = 'green', label = 'Best Epoch')  
    ax.legend(loc = 1)    
    ax.set_ylim([0.4, 1])

    ax.set_xlabel(xlabel)
    ax.set_ylabel('Accuracy (Fraction)')
    
    plt.show()
    
def model_to_string(model):
    import re
    stringlist = []
    model.summary(print_fn=lambda x: stringlist.append(x))
    sms = "\n".join(stringlist)
    sms = re.sub('_\d\d\d','', sms)
    sms = re.sub('_\d\d','', sms)
    sms = re.sub('_\d','', sms)  
    return sms

# %% [markdown]
# In this notebook, we will:
#
# - Use a pre-built CNN function to classify roads vs. dogs.
# - Build neural networks from scratch in Keras.
# - Experiment with building CNN models from scratch in Keras.
# - (Advanced, Optional) Build CNN models for distinguishing cats from dogs, and even experiment with implementing a famous architecture!

# %% [markdown]
# **Change Hardware Accelerator to GPU to train faster (Runtime -> Change Runtime Type -> Hardware Accelerator -> GPU)**

# %% [markdown]
# #Loading in Data

# %% [markdown]
# Once again, let's load in our dog/road dataset and create our training and test set. **What's the shape of each dataset? Why?**

# %%
# load our data
data, labels = load_data()
data = data.astype(float)
labels = categorical_to_numpy(labels)
inputs_train, inputs_test, labels_train, labels_test = model_selection.train_test_split(data, labels, test_size=0.2, random_state=1)

# %% [markdown]
# # Models for Vision: Convolutional Neural Networks

# %% [markdown]
# ###Exercise: Exploring Hyperparameters ✍️
#
# As you know, there is a famous type of neural network known as convolutional neural networks (CNNs). These types of neural networks work particularly well on problems to do with computer vision. Let's try one out!
#
# To load up a simple CNN on scikit-learn, just run:
#
# `cnn = CNNClassifier(num_epochs, layers, dropout)`
#
# Work with your instructors to review what each parameter means and how it affects the model! The **dropout** represents how many weights we set to 0 during training time, which can help prevent overfitting.
#
# **Try different values of num_epochs, layers, and dropout so that you get the best possible accuracy on the test set using `model.score()`**!

# %%
cnn = CNNClassifier(10, 6, 0.3) #dropout is the percentage of how many weights are 0 (connected)
cnn.fit(inputs_train, labels_train)
preds = cnn.predict(inputs_test)
print (cnn.score(inputs_test, labels_test))
# Out:
# Epoch 1/10
# 96/96 - 8s - loss: 0.6810 - accuracy: 0.7312
# Epoch 2/10
# 96/96 - 0s - loss: 0.2977 - accuracy: 0.8823
# Epoch 3/10
# 96/96 - 0s - loss: 0.2253 - accuracy: 0.9167
# Epoch 4/10
# 96/96 - 0s - loss: 0.2008 - accuracy: 0.9240
# Epoch 5/10
# 96/96 - 0s - loss: 0.1506 - accuracy: 0.9500
# Epoch 6/10
# 96/96 - 0s - loss: 0.1660 - accuracy: 0.9427
# Epoch 7/10
# 96/96 - 0s - loss: 0.1472 - accuracy: 0.9469
# Epoch 8/10
# 96/96 - 0s - loss: 0.1067 - accuracy: 0.9604
# Epoch 9/10
# 96/96 - 0s - loss: 0.1115 - accuracy: 0.9698
# Epoch 10/10
# 96/96 - 0s - loss: 0.0931 - accuracy: 0.9688
# 24/24 - 0s
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/engine/sequential.py:450: UserWarning: `model.predict_classes()` is deprecated and will be removed after 2021-01-01. Please use instead:* `np.argmax(model.predict(x), axis=-1)`,   if your model does multi-class classification   (e.g. if it uses a `softmax` last-layer activation).* `(model.predict(x) > 0.5).astype("int32")`,   if your model does binary classification   (e.g. if it uses a `sigmoid` last-layer activation).
#   warnings.warn('`model.predict_classes()` is deprecated and '
# 24/24 - 0s - loss: 0.1237 - accuracy: 0.9583
# 0.9583333134651184

# %%
### YOUR CODE HERE

# Create and train our multi layer perceptron model
cnn = CNNClassifier(num_epochs=7, layers=1, dropout=0.5)

cnn.fit(inputs_train, labels_train)

# Print the score on the testing data
print("CNN Testing Set Score:")
print (cnn.score(inputs_test, labels_test))
### END CODE
# Out:
# Epoch 1/7
# 96/96 - 1s - loss: 23.1620 - accuracy: 0.5500
# Epoch 2/7
# 96/96 - 0s - loss: 5.1189 - accuracy: 0.6375
# Epoch 3/7
# 96/96 - 0s - loss: 1.5053 - accuracy: 0.7427
# Epoch 4/7
# 96/96 - 0s - loss: 0.8180 - accuracy: 0.7990
# Epoch 5/7
# 96/96 - 0s - loss: 0.4718 - accuracy: 0.8458
# Epoch 6/7
# 96/96 - 0s - loss: 0.4166 - accuracy: 0.8635
# Epoch 7/7
# 96/96 - 0s - loss: 0.3125 - accuracy: 0.9010
# CNN Testing Set Score:
# 24/24 - 0s - loss: 0.1396 - accuracy: 0.9500
# 0.949999988079071

# %% [markdown]
# **How well did your neural network perform?**
#
# CNNs typically perform better than fully-connected neural networks on vision problems, but, as before, they aren't always consistent. They are also sensitive to a number of parameters.

# %% [markdown]
# ## Training and Validation Curves
#
# An important aspect of training neural networks is to prevent overfitting. **How would we recognize overfitting?**
#
# In the first line of code below, we first **fit** the model on the training data and pass in some validation (or test) data to evaluate it. We call it the **history** because we want to retain information about the accuracy at each epoch.
#
# In the second line we plot the history so that we can compare the training and validation accuracies.
#
# ```
# history = model.fit(inputs_train, labels_train, validation_data=(inputs_test, labels_test))
# plot_acc(history)
# ```

# %% [markdown]
# ###Exercise: Plotting a training vs. validation curve for out CNN ✍️
#
# **After how many epochs does the model begin to overfit? How does this vary as you vary the number of hidden layers and dropout?** Overfitting occurs when the validation accuracy starts to drop below the training accuracy.

# %%
### YOUR CODE HERE
history = cnn.fit(inputs_train, labels_train, validation_data=(inputs_test, labels_test))
plot_acc(history)
### END CODE
# Out:
# Epoch 1/7
# 96/96 - 1s - loss: 5.3796 - accuracy: 0.6302 - val_loss: 0.4253 - val_accuracy: 0.8667
# Epoch 2/7
# 96/96 - 0s - loss: 1.0967 - accuracy: 0.7719 - val_loss: 0.1958 - val_accuracy: 0.9125
# Epoch 3/7
# 96/96 - 0s - loss: 0.5363 - accuracy: 0.8438 - val_loss: 0.1782 - val_accuracy: 0.9250
# Epoch 4/7
# 96/96 - 0s - loss: 0.4065 - accuracy: 0.8635 - val_loss: 0.1620 - val_accuracy: 0.9500
# Epoch 5/7
# 96/96 - 0s - loss: 0.2847 - accuracy: 0.8927 - val_loss: 0.1571 - val_accuracy: 0.9458
# Epoch 6/7
# 96/96 - 0s - loss: 0.3110 - accuracy: 0.8958 - val_loss: 0.1738 - val_accuracy: 0.9375
# Epoch 7/7
# 96/96 - 0s - loss: 0.2433 - accuracy: 0.9125 - val_loss: 0.1651 - val_accuracy: 0.9333

# %% [markdown]
# # Building Neural Networks from Scratch in Keras
#
# So far, we've used helper functions which pre-build Keras neural network models. Now, we will build them on our own!
#
# Let's start with a "toy example": a tiny neural network with 3 inputs.

# %% [markdown]
# ###Exercise: Building a simple Neural Network using Keras! ✍️

# %% [markdown]
# We're going to build this model:
#
# ![](http://cs231n.github.io/assets/nn1/neural_net.jpeg)

# %% [markdown]
# This network can be described as:
# * Input Layer: 3
# * Layer 1 (Hidden): 4 neurons that are activated by `'relu'`
# * Layer 2 (Output): 2 neurons that are activated by `'softmax'`
#
#
# We also want to compile the model with
# `loss = 'categorical_crossentropy'`
#
# Try filling in the blanks below and walking through each line! **If you want a hint or more details, check out the optional reference below.**

# %%
# Fill in the blanks with your group!
### YOUR CODE HERE:
model_1 = Sequential()
model_1.add(Dense(4, input_shape = (3,), activation = 'relu'))
model_1.add(Dense(2, activation = 'softmax'))
model_1.compile(loss='categorical_crossentropy',
                optimizer = 'adam', 
                metrics = ['accuracy'])
model_1.predict_classes([[100,-4,-2]]) #Try any input!
### END CODE
# Out:
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/engine/sequential.py:450: UserWarning: `model.predict_classes()` is deprecated and will be removed after 2021-01-01. Please use instead:* `np.argmax(model.predict(x), axis=-1)`,   if your model does multi-class classification   (e.g. if it uses a `softmax` last-layer activation).* `(model.predict(x) > 0.5).astype("int32")`,   if your model does binary classification   (e.g. if it uses a `sigmoid` last-layer activation).
#   warnings.warn('`model.predict_classes()` is deprecated and '
# array([1])

# %% [markdown]
# ####**Optional Reference**
#
# Here's some information about each step of the process. **You don't need to read through all this - check it as a reference if needed!**
#
# **1. Specify model**
#
# ```
# model = Sequential()
# ```
# In this line of code, we build our network where the information flows from LEFT to RIGHT through the network in ONE DIRECTION as opposed to multiple directions. Neurons on the right never pass informations to neurons on the left of it.
#
#
# **2. Add layers to the network**
# ```
# model.add(Dense(4,input_shape = (3,), activation = 'sigmoid'))
# ```
# In this code, we `add` a `layer` of neurons to our network.
#
# This layers consists of 4 neurons. Each neuron is DENSE and connects to all of the previous layer's inputs and all of the subsequent layers outputs. We specify that there are 3 inputs here.
#
# We also specify what kind of output the neuron will give. If you want the neuron to output a number between 0 and 1 (like a probability!) you would use 'softmax' or 'sigmoid'. If you want the neuron to output any number, you can use 'linear'! You'll also often see 'relu', which is when a neuron will only output positive numbers.
#
# ```
# model.add(Dense(1, activation = 'linear'))
# ```
# This code adds ANOTHER layer to the network that has 1 neuron. This one neuron is used to predict a continuous value!
#
# **3. Turn the model on by compiling it**
#
# After having built the network, we want to train and use it, so we have to 'compile' it to prepare. We have to specify at the very least: a loss (how the model measures the quality of its weights), an optimizer (which adjusts the weights), and a metric (how to evaluate our results). Here are some common choices:
# ```
# model.compile(loss='mean_squared_error',
# optimizer = 'adam',
# metrics = ['mean_squared_error'])
#   ```
#
# Once we've created our network, we can use it very simply! Just like we did with sklearn, we define our input data (x), the true predictions from that data (y), and then train our model with `fit`.
#
# ```
# model.fit(x, y)
# ```
#
# To use the model, you can use it to predict something with:
# ```
# y = model.predict_classes(x)
# ```
#
# You can actually use the model before you even train it! It just won't perform very well.

# %% [markdown]
# ###(Optional) Exercise: Building a multi-layer Neural Net using Keras ✍️
#
# ![](http://cs231n.github.io/assets/nn1/neural_net2.jpeg)
#
# Let's try another, bigger example!
#
# * Input Layer: 3 Neurons
#
# * Layer 1: 4 neurons that are activated by `'relu' `and take in 3 inputs.
#
# * Layer 2: 4 neurons that are activated by `'relu'`
#
# * Layer 3 (out): 1 neurons that is activated by `'sigmoid'`
#
# Compile the model with
# `loss = 'binary_crossentropy'`

# %%
### YOUR CODE HERE
model_1 = Sequential()
model_1.add(Dense(4, input_shape = (3,), activation = 'relu'))
model_1.add(Dense(4, activation = 'relu'))
model_1.add(Dense(1, activation = 'sigmoid'))
model_1.compile(loss='binary_crossentropy',
                optimizer = 'adam', 
                metrics = ['accuracy'])
model_1.predict_classes([[100,-4,-2]])
### END CODE
# Out:
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/engine/sequential.py:450: UserWarning: `model.predict_classes()` is deprecated and will be removed after 2021-01-01. Please use instead:* `np.argmax(model.predict(x), axis=-1)`,   if your model does multi-class classification   (e.g. if it uses a `softmax` last-layer activation).* `(model.predict(x) > 0.5).astype("int32")`,   if your model does binary classification   (e.g. if it uses a `sigmoid` last-layer activation).
#   warnings.warn('`model.predict_classes()` is deprecated and '
# array([[1]], dtype=int32)

# %% [markdown]
# ##Exercise: Building a CNN using Keras! ✍️
#
# Now that we know how to build simple neural networks in Keras, let's build a CNN that will perform well on our data set of car and road images.
#
# Below is Keras code for a CNN. It will run as-is on the conscientious cars dataset. However, the performance is suboptimal. Add more layers and change the neural network hyperparameters so that the performance will be better. **Can you get the train and validation accuracy to both be higher than 90%?**
#
# The Keras core layer API may be a useful reference: https://keras.io/layers/core/
#
# In particular and in addition to adding more of the existing convolutional layers and activations, consider using the following layers after a convolution + activation:
#
# `Dropout(N)`
#
# `MaxPooling2D(pool_size=(N, N))`

# %%
model = Sequential()
model.add(Reshape((32, 32, 3)))

model.add(Conv2D(32, (3, 3), padding='same'))
model.add(Activation('relu'))

model.add(Conv2D(32, (3, 3), padding='same'))
model.add(Activation('relu'))

model.add(Conv2D(32, (3, 3), padding='same'))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(Flatten())
model.add(Dense(512))
model.add(Activation('relu'))
model.add(Dense(2))
model.add(Activation('softmax'))

# initiate RMSprop optimizer
opt = keras.optimizers.RMSprop(lr=0.0001, decay=1e-6)

# Let's train the model using RMSprop
model.compile(loss='categorical_crossentropy',
              optimizer=opt,
              metrics=['accuracy'])

# Train the CNN and plot accuracy.
history = model.fit(inputs_train, labels_train, \
                    validation_data=(inputs_test, labels_test), \
                    epochs=55)
plot_acc(history)
# Out:
# Epoch 1/55
# 30/30 [==============================] - 1s 20ms/step - loss: 34.6898 - accuracy: 0.6050 - val_loss: 0.5465 - val_accuracy: 0.9417
# Epoch 2/55
# 30/30 [==============================] - 0s 8ms/step - loss: 1.5450 - accuracy: 0.8966 - val_loss: 0.4324 - val_accuracy: 0.9500
# Epoch 3/55
# 30/30 [==============================] - 0s 7ms/step - loss: 1.1214 - accuracy: 0.9056 - val_loss: 0.2201 - val_accuracy: 0.9583
# Epoch 4/55
# 30/30 [==============================] - 0s 7ms/step - loss: 0.5701 - accuracy: 0.9340 - val_loss: 0.2582 - val_accuracy: 0.9375
# Epoch 5/55
# 30/30 [==============================] - 0s 6ms/step - loss: 0.6040 - accuracy: 0.9322 - val_loss: 0.3634 - val_accuracy: 0.9583
# Epoch 6/55
# 30/30 [==============================] - 0s 7ms/step - loss: 0.1705 - accuracy: 0.9690 - val_loss: 4.5824 - val_accuracy: 0.6375
# Epoch 7/55
# 30/30 [==============================] - 0s 7ms/step - loss: 0.6576 - accuracy: 0.9405 - val_loss: 6.4677 - val_accuracy: 0.5667
# Epoch 8/55
# 30/30 [==============================] - 0s 7ms/step - loss: 0.4487 - accuracy: 0.9438 - val_loss: 0.2720 - val_accuracy: 0.9583
# Epoch 9/55
# 30/30 [==============================] - 0s 7ms/step - loss: 0.0501 - accuracy: 0.9910 - val_loss: 0.3745 - val_accuracy: 0.9333
# Epoch 10/55
# 30/30 [==============================] - 0s 6ms/step - loss: 0.0248 - accuracy: 0.9940 - val_loss: 0.3213 - val_accuracy: 0.9417
# Epoch 11/55
# 30/30 [==============================] - 0s 7ms/step - loss: 0.0764 - accuracy: 0.9887 - val_loss: 0.3223 - val_accuracy: 0.9500
# Epoch 12/55
# 30/30 [==============================] - 0s 7ms/step - loss: 2.3509e-04 - accuracy: 1.0000 - val_loss: 0.3229 - val_accuracy: 0.9458
# Epoch 13/55
# 30/30 [==============================] - 0s 6ms/step - loss: 1.5823e-04 - accuracy: 1.0000 - val_loss: 0.3390 - val_accuracy: 0.9500
# Epoch 14/55
# 30/30 [==============================] - 0s 7ms/step - loss: 8.7398e-04 - accuracy: 0.9998 - val_loss: 7.0825 - val_accuracy: 0.5875
# Epoch 15/55
# 30/30 [==============================] - 0s 7ms/step - loss: 0.6418 - accuracy: 0.9359 - val_loss: 0.3721 - val_accuracy: 0.9458
# Epoch 16/55
# 30/30 [==============================] - 0s 7ms/step - loss: 0.0132 - accuracy: 0.9980 - val_loss: 0.4098 - val_accuracy: 0.9292
# Epoch 17/55
# 30/30 [==============================] - 0s 7ms/step - loss: 1.2033e-04 - accuracy: 1.0000 - val_loss: 0.3484 - val_accuracy: 0.9583
# Epoch 18/55
# 30/30 [==============================] - 0s 7ms/step - loss: 0.0223 - accuracy: 0.9976 - val_loss: 0.3531 - val_accuracy: 0.9375
# Epoch 19/55
# 30/30 [==============================] - 0s 7ms/step - loss: 5.2252e-04 - accuracy: 1.0000 - val_loss: 0.3445 - val_accuracy: 0.9458
# Epoch 20/55
# 30/30 [==============================] - 0s 7ms/step - loss: 3.2977e-05 - accuracy: 1.0000 - val_loss: 0.3466 - val_accuracy: 0.9500
# Epoch 21/55
# 30/30 [==============================] - 0s 7ms/step - loss: 6.7969e-06 - accuracy: 1.0000 - val_loss: 0.3588 - val_accuracy: 0.9500
# Epoch 22/55
# 30/30 [==============================] - 0s 6ms/step - loss: 2.8584e-06 - accuracy: 1.0000 - val_loss: 0.3573 - val_accuracy: 0.9500
# Epoch 23/55
# 30/30 [==============================] - 0s 7ms/step - loss: 1.6657e-06 - accuracy: 1.0000 - val_loss: 0.4058 - val_accuracy: 0.9417
# Epoch 24/55
# 30/30 [==============================] - 0s 7ms/step - loss: 1.2459e-06 - accuracy: 1.0000 - val_loss: 1.0977 - val_accuracy: 0.9042
# Epoch 25/55
# 30/30 [==============================] - 0s 7ms/step - loss: 0.4478 - accuracy: 0.9490 - val_loss: 0.5167 - val_accuracy: 0.9583
# Epoch 26/55
# 30/30 [==============================] - 0s 7ms/step - loss: 8.9090e-04 - accuracy: 1.0000 - val_loss: 0.3389 - val_accuracy: 0.9625
# Epoch 27/55
# 30/30 [==============================] - 0s 7ms/step - loss: 3.0332e-06 - accuracy: 1.0000 - val_loss: 0.3425 - val_accuracy: 0.9625
# Epoch 28/55
# 30/30 [==============================] - 0s 6ms/step - loss: 1.3182e-06 - accuracy: 1.0000 - val_loss: 0.3520 - val_accuracy: 0.9625
# Epoch 29/55
# 30/30 [==============================] - 0s 7ms/step - loss: 6.9760e-07 - accuracy: 1.0000 - val_loss: 0.3638 - val_accuracy: 0.9542
# Epoch 30/55
# 30/30 [==============================] - 0s 7ms/step - loss: 3.2826e-07 - accuracy: 1.0000 - val_loss: 0.4514 - val_accuracy: 0.9250
# Epoch 31/55
# 30/30 [==============================] - 0s 7ms/step - loss: 0.6192 - accuracy: 0.9479 - val_loss: 0.4051 - val_accuracy: 0.9500
# Epoch 32/55
# 30/30 [==============================] - 0s 6ms/step - loss: 3.8517e-06 - accuracy: 1.0000 - val_loss: 0.3957 - val_accuracy: 0.9500
# Epoch 33/55
# 30/30 [==============================] - 0s 7ms/step - loss: 2.8185e-06 - accuracy: 1.0000 - val_loss: 0.4022 - val_accuracy: 0.9500
# Epoch 34/55
# 30/30 [==============================] - 0s 7ms/step - loss: 1.2516e-06 - accuracy: 1.0000 - val_loss: 0.4106 - val_accuracy: 0.9542
# Epoch 35/55
# 30/30 [==============================] - 0s 6ms/step - loss: 4.6896e-07 - accuracy: 1.0000 - val_loss: 0.4223 - val_accuracy: 0.9500
# Epoch 36/55
# 30/30 [==============================] - 0s 7ms/step - loss: 2.7253e-07 - accuracy: 1.0000 - val_loss: 0.4250 - val_accuracy: 0.9542
# Epoch 37/55
# 30/30 [==============================] - 0s 7ms/step - loss: 0.0486 - accuracy: 0.9955 - val_loss: 0.4918 - val_accuracy: 0.9500
# Epoch 38/55
# 30/30 [==============================] - 0s 7ms/step - loss: 0.0016 - accuracy: 0.9982 - val_loss: 0.4713 - val_accuracy: 0.9333
# Epoch 39/55
# 30/30 [==============================] - 0s 7ms/step - loss: 6.2393e-07 - accuracy: 1.0000 - val_loss: 0.4723 - val_accuracy: 0.9333
# Epoch 40/55
# 30/30 [==============================] - 0s 7ms/step - loss: 6.4291e-07 - accuracy: 1.0000 - val_loss: 0.4686 - val_accuracy: 0.9375
# Epoch 41/55
# 30/30 [==============================] - 0s 7ms/step - loss: 1.7081e-07 - accuracy: 1.0000 - val_loss: 0.4765 - val_accuracy: 0.9333
# Epoch 42/55
# 30/30 [==============================] - 0s 7ms/step - loss: 1.3424e-07 - accuracy: 1.0000 - val_loss: 0.4721 - val_accuracy: 0.9375
# Epoch 43/55
# 30/30 [==============================] - 0s 7ms/step - loss: 1.1559e-07 - accuracy: 1.0000 - val_loss: 0.4743 - val_accuracy: 0.9375
# Epoch 44/55
# 30/30 [==============================] - 0s 7ms/step - loss: 5.6226e-08 - accuracy: 1.0000 - val_loss: 0.4783 - val_accuracy: 0.9375
# Epoch 45/55
# 30/30 [==============================] - 0s 7ms/step - loss: 2.9599e-08 - accuracy: 1.0000 - val_loss: 0.4896 - val_accuracy: 0.9417
# Epoch 46/55
# 30/30 [==============================] - 0s 7ms/step - loss: 0.0482 - accuracy: 0.9953 - val_loss: 0.4966 - val_accuracy: 0.9500
# Epoch 47/55
# 30/30 [==============================] - 0s 7ms/step - loss: 3.4702e-05 - accuracy: 1.0000 - val_loss: 0.5058 - val_accuracy: 0.9417
# Epoch 48/55
# 30/30 [==============================] - 0s 7ms/step - loss: 6.7550e-07 - accuracy: 1.0000 - val_loss: 0.5210 - val_accuracy: 0.9458
# Epoch 49/55
# 30/30 [==============================] - 0s 7ms/step - loss: 6.7693e-07 - accuracy: 1.0000 - val_loss: 0.5175 - val_accuracy: 0.9458
# Epoch 50/55
# 30/30 [==============================] - 0s 7ms/step - loss: 1.5813e-07 - accuracy: 1.0000 - val_loss: 0.5272 - val_accuracy: 0.9458
# Epoch 51/55
# 30/30 [==============================] - 0s 7ms/step - loss: 8.2889e-08 - accuracy: 1.0000 - val_loss: 0.5304 - val_accuracy: 0.9458
# Epoch 52/55
# 30/30 [==============================] - 0s 7ms/step - loss: 3.5240e-08 - accuracy: 1.0000 - val_loss: 0.5391 - val_accuracy: 0.9458
# Epoch 53/55
# 30/30 [==============================] - 0s 7ms/step - loss: 1.3333e-08 - accuracy: 1.0000 - val_loss: 0.5634 - val_accuracy: 0.9375
# Epoch 54/55
# 30/30 [==============================] - 0s 7ms/step - loss: 1.6982e-08 - accuracy: 1.0000 - val_loss: 0.5735 - val_accuracy: 0.9500
# Epoch 55/55
# 30/30 [==============================] - 0s 7ms/step - loss: 0.0476 - accuracy: 0.9918 - val_loss: 0.6004 - val_accuracy: 0.9500

# %% [markdown]
# **What interesting observations** do you make from the graph? How many epochs should you train for?
#
# We can also print out the structure of our model. What do the parts of the summary mean?

# %%
model.summary()
# Out:
# Model: "sequential_7"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# reshape_4 (Reshape)          (None, 32, 32, 3)         0
# _________________________________________________________________
# conv2d_26 (Conv2D)           (None, 32, 32, 32)        896
# _________________________________________________________________
# activation_34 (Activation)   (None, 32, 32, 32)        0
# _________________________________________________________________
# conv2d_27 (Conv2D)           (None, 32, 32, 32)        9248
# _________________________________________________________________
# activation_35 (Activation)   (None, 32, 32, 32)        0
# _________________________________________________________________
# conv2d_28 (Conv2D)           (None, 32, 32, 32)        9248
# _________________________________________________________________
# activation_36 (Activation)   (None, 32, 32, 32)        0
# _________________________________________________________________
# max_pooling2d_8 (MaxPooling2 (None, 16, 16, 32)        0
# _________________________________________________________________
# flatten_4 (Flatten)          (None, 8192)              0
# _________________________________________________________________
# dense_16 (Dense)             (None, 512)               4194816
# _________________________________________________________________
# activation_37 (Activation)   (None, 512)               0
# _________________________________________________________________
# dense_17 (Dense)             (None, 2)                 1026
# _________________________________________________________________
# activation_38 (Activation)   (None, 2)                 0
# =================================================================
# Total params: 4,215,234
# Trainable params: 4,215,234
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# #Advanced: Cats vs. Dogs with CNN
#
# So far, we've trained a CNN to distinguish between small images of cats and small images of dogs. It's more challenging and time-consuming to train CNNs for bigger images or harder tasks, like distinguishing dogs from cats (which look a lot more like dogs than roads do!)
#
# In this exercise, you'll adapt your previous model to classify large images of dogs vs. cats, and then try implementing a famous CNN architecture. Along the way, you'll deal with some of the debugging that machine learning engineers often have to handle.

# %%
#@title Run this to load cat and dog data. { display-mode: "form" }

#Code here from https://colab.research.google.com/github/google/eng-edu/blob/master/ml/pc/exercises/image_classification_part1.ipynb#scrollTo=4PIP1rkmeAYS

import tensorflow as tf
import os 
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from google.colab.patches import cv2_imshow
import cv2
import matplotlib.pyplot as plt

try:
  road_model = model
  road_saved = True
except NameError:
  road_saved = False

IMG_SHAPE  = 150  # Our training data consists of images with width of 150 pixels and height of 150 pixels
_URL = 'https://storage.googleapis.com/mledu-datasets/cats_and_dogs_filtered.zip'
zip_dir = tf.keras.utils.get_file('cats_and_dogs_filterted.zip', origin=_URL, extract=True)
base_dir = os.path.join(os.path.dirname(zip_dir), 'cats_and_dogs_filtered')
train_dir = os.path.join(base_dir, 'train')
validation_dir = os.path.join(base_dir, 'validation')

train_cats_dir = os.path.join(train_dir, 'cats')  # directory with our training cat pictures
train_dogs_dir = os.path.join(train_dir, 'dogs')  # directory with our training dog pictures
validation_cats_dir = os.path.join(validation_dir, 'cats')  # directory with our validation cat pictures
validation_dogs_dir = os.path.join(validation_dir, 'dogs')  # directory with our validation dog pictures
train_image_generator      = ImageDataGenerator()  # Generator for our training data
validation_image_generator = ImageDataGenerator()  # Generator for our validation data
train_data = train_image_generator.flow_from_directory(batch_size=2000,
                                                           directory=train_dir,
                                                           shuffle=True,
                                                           target_size=(IMG_SHAPE,IMG_SHAPE), #(150,150)
                                                           class_mode='binary').next()
val_data = validation_image_generator.flow_from_directory(batch_size=1000,
                                                              directory=validation_dir,
                                                              shuffle=False,
                                                              target_size=(IMG_SHAPE,IMG_SHAPE), #(150,150)

                                                              class_mode='binary').next()
cd_train_inputs, cd_train_labels = train_data
cd_test_inputs, cd_test_labels = val_data
# Out:
# Downloading data from https://storage.googleapis.com/mledu-datasets/cats_and_dogs_filtered.zip
# 68608000/68606236 [==============================] - 0s 0us/step
# Found 2000 images belonging to 2 classes.
# Found 1000 images belonging to 2 classes.

# %% [markdown]
# **Run the code below to see the dimensions of our training and validation data. What does each number mean? What is different than our previous dataset?**

# %%
print (cd_train_inputs.shape) 
print (cd_train_labels.shape) 
print (cd_test_inputs.shape) 
print (cd_test_labels.shape)
# Out:
# (2000, 150, 150, 3)
# (2000,)
# (1000, 150, 150, 3)
# (1000,)

# %% [markdown]
# **Run this code to see a random image from our training data (different each time).**

# %%
index = np.random.randint(len(cd_train_inputs))
plt.imshow(cd_train_inputs[index]/255)
plt.show()
print("Label:",cd_train_labels[index])
# Out:
# Label: 0.0

# %% [markdown]
# **By adapting code from the previous exercise, build, train, and test a CNN to classify cats vs. dogs.**
# **Hints:**
# *   Use print(model.summary()) for a useful visualization of your model's architecture. Compare the summary of your cat/road and cat/dog classifiers.
# *  Substitute the names of the new datasets.
# *  Get a "first try" working by making small adjustments to a previous model before trying to optimize the accuracy. You can temporarily comment out layers as you figure things out.
# *  The outputs have different shapes betweeen the two datasets. What do you need to change? (You will get an ValueError that suggests how to transform the output to a one-hot encoding.)
# *  If you run out of memory, restart the notebook and/or use your knowledge of convolution arithmetic to reduce the size of an intermediate output (see [Keras documentation](https://www.tensorflow.org/api_docs/python/tf/keras/layers/Conv2D)).
# * Dropout layers help reduce overfitting.

# %%
model = Sequential()
#TODO: Your code here to build, train, and test a cats vs. dogs CNN!
#If you run into errors, see the hints above for help debugging! 
model.add(Reshape((32, 32, 3)))

model.add(Conv2D(32, (3, 3), padding='same'))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(Conv2D(32, (3, 3), padding='same'))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(Conv2D(32, (3, 3), padding='same'))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(Conv2D(32, (3, 3), padding='same'))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(Conv2D(32, (3, 3), padding='same'))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(Flatten())
model.add(Dense(512))
model.add(Activation('relu'))
model.add(Dense(2))
model.add(Activation('softmax'))

# initiate RMSprop optimizer
opt = keras.optimizers.RMSprop(lr=0.0001, decay=1e-6)

# Let's train the model using RMSprop
model.compile(loss='categorical_crossentropy',
              optimizer=opt,
              metrics=['accuracy'])

# Train the CNN and plot accuracy.
history = model.fit(inputs_train, labels_train, \
                    validation_data=(inputs_test, labels_test), \
                    epochs=70)
plot_acc(history)
# Out:
# Epoch 1/70
# 30/30 [==============================] - 1s 14ms/step - loss: 0.7797 - accuracy: 0.6379 - val_loss: 0.3351 - val_accuracy: 0.8583
# Epoch 2/70
# 30/30 [==============================] - 0s 5ms/step - loss: 0.3604 - accuracy: 0.8491 - val_loss: 0.2399 - val_accuracy: 0.9083
# Epoch 3/70
# 30/30 [==============================] - 0s 6ms/step - loss: 0.2536 - accuracy: 0.8945 - val_loss: 0.2046 - val_accuracy: 0.9250
# Epoch 4/70
# 30/30 [==============================] - 0s 6ms/step - loss: 0.1843 - accuracy: 0.9349 - val_loss: 0.1914 - val_accuracy: 0.9375
# Epoch 5/70
# 30/30 [==============================] - 0s 5ms/step - loss: 0.1468 - accuracy: 0.9516 - val_loss: 0.1532 - val_accuracy: 0.9500
# Epoch 6/70
# 30/30 [==============================] - 0s 5ms/step - loss: 0.1655 - accuracy: 0.9264 - val_loss: 0.2643 - val_accuracy: 0.8792
# Epoch 7/70
# 30/30 [==============================] - 0s 5ms/step - loss: 0.1420 - accuracy: 0.9442 - val_loss: 0.2085 - val_accuracy: 0.9125
# Epoch 8/70
# 30/30 [==============================] - 0s 5ms/step - loss: 0.1118 - accuracy: 0.9544 - val_loss: 0.1330 - val_accuracy: 0.9583
# Epoch 9/70
# 30/30 [==============================] - 0s 5ms/step - loss: 0.1356 - accuracy: 0.9529 - val_loss: 0.1915 - val_accuracy: 0.9292
# Epoch 10/70
# 30/30 [==============================] - 0s 5ms/step - loss: 0.0992 - accuracy: 0.9601 - val_loss: 0.1344 - val_accuracy: 0.9583
# Epoch 11/70
# 30/30 [==============================] - 0s 5ms/step - loss: 0.0896 - accuracy: 0.9635 - val_loss: 0.1649 - val_accuracy: 0.9542
# Epoch 12/70
# 30/30 [==============================] - 0s 5ms/step - loss: 0.0785 - accuracy: 0.9668 - val_loss: 0.2287 - val_accuracy: 0.9208
# Epoch 13/70
# 30/30 [==============================] - 0s 5ms/step - loss: 0.0900 - accuracy: 0.9570 - val_loss: 0.1387 - val_accuracy: 0.9542
# Epoch 14/70
# 30/30 [==============================] - 0s 5ms/step - loss: 0.0458 - accuracy: 0.9866 - val_loss: 0.1361 - val_accuracy: 0.9542
# Epoch 15/70
# 30/30 [==============================] - 0s 5ms/step - loss: 0.0556 - accuracy: 0.9755 - val_loss: 0.1386 - val_accuracy: 0.9583
# Epoch 16/70
# 30/30 [==============================] - 0s 5ms/step - loss: 0.0310 - accuracy: 0.9903 - val_loss: 0.2103 - val_accuracy: 0.9458
# Epoch 17/70
# 30/30 [==============================] - 0s 5ms/step - loss: 0.0415 - accuracy: 0.9845 - val_loss: 0.1477 - val_accuracy: 0.9583
# Epoch 18/70
# 30/30 [==============================] - 0s 5ms/step - loss: 0.0353 - accuracy: 0.9894 - val_loss: 0.1553 - val_accuracy: 0.9625
# Epoch 19/70
# 30/30 [==============================] - 0s 5ms/step - loss: 0.0313 - accuracy: 0.9870 - val_loss: 0.1856 - val_accuracy: 0.9333
# Epoch 20/70
# 30/30 [==============================] - 0s 5ms/step - loss: 0.0221 - accuracy: 0.9973 - val_loss: 0.1525 - val_accuracy: 0.9583
# Epoch 21/70
# 30/30 [==============================] - 0s 5ms/step - loss: 0.0307 - accuracy: 0.9905 - val_loss: 0.1644 - val_accuracy: 0.9625
# Epoch 22/70
# 30/30 [==============================] - 0s 5ms/step - loss: 0.0154 - accuracy: 0.9976 - val_loss: 0.1477 - val_accuracy: 0.9583
# Epoch 23/70
# 30/30 [==============================] - 0s 5ms/step - loss: 0.0125 - accuracy: 0.9973 - val_loss: 0.1581 - val_accuracy: 0.9667
# Epoch 24/70
# 30/30 [==============================] - 0s 5ms/step - loss: 0.0107 - accuracy: 0.9985 - val_loss: 0.1722 - val_accuracy: 0.9583
# Epoch 25/70
# 30/30 [==============================] - 0s 5ms/step - loss: 0.0080 - accuracy: 0.9991 - val_loss: 0.2148 - val_accuracy: 0.9500
# Epoch 26/70
# 30/30 [==============================] - 0s 5ms/step - loss: 0.0112 - accuracy: 0.9958 - val_loss: 0.7137 - val_accuracy: 0.8083
# Epoch 27/70
# 30/30 [==============================] - 0s 5ms/step - loss: 0.0221 - accuracy: 0.9946 - val_loss: 0.1747 - val_accuracy: 0.9542
# Epoch 28/70
# 30/30 [==============================] - 0s 5ms/step - loss: 0.0079 - accuracy: 0.9986 - val_loss: 0.1751 - val_accuracy: 0.9667
# Epoch 29/70
# 30/30 [==============================] - 0s 5ms/step - loss: 0.0039 - accuracy: 1.0000 - val_loss: 0.1829 - val_accuracy: 0.9583
# Epoch 30/70
# 30/30 [==============================] - 0s 5ms/step - loss: 0.0180 - accuracy: 0.9915 - val_loss: 0.1824 - val_accuracy: 0.9583
# Epoch 31/70
# 30/30 [==============================] - 0s 5ms/step - loss: 0.0034 - accuracy: 1.0000 - val_loss: 0.1924 - val_accuracy: 0.9667
# Epoch 32/70
# 30/30 [==============================] - 0s 5ms/step - loss: 0.0109 - accuracy: 0.9971 - val_loss: 0.2207 - val_accuracy: 0.9500
# Epoch 33/70
# 30/30 [==============================] - 0s 5ms/step - loss: 0.0064 - accuracy: 0.9984 - val_loss: 0.1799 - val_accuracy: 0.9667
# Epoch 34/70
# 30/30 [==============================] - 0s 5ms/step - loss: 0.0022 - accuracy: 1.0000 - val_loss: 0.1925 - val_accuracy: 0.9583
# Epoch 35/70
# 30/30 [==============================] - 0s 5ms/step - loss: 0.0064 - accuracy: 0.9987 - val_loss: 0.1941 - val_accuracy: 0.9583
# Epoch 36/70
# 30/30 [==============================] - 0s 5ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.2000 - val_accuracy: 0.9583
# Epoch 37/70
# 30/30 [==============================] - 0s 5ms/step - loss: 0.0051 - accuracy: 0.9986 - val_loss: 0.2116 - val_accuracy: 0.9583
# Epoch 38/70
# 30/30 [==============================] - 0s 5ms/step - loss: 7.9135e-04 - accuracy: 1.0000 - val_loss: 0.2207 - val_accuracy: 0.9500
# Epoch 39/70
# 30/30 [==============================] - 0s 5ms/step - loss: 0.0110 - accuracy: 0.9945 - val_loss: 0.2371 - val_accuracy: 0.9500
# Epoch 40/70
# 30/30 [==============================] - 0s 5ms/step - loss: 7.4738e-04 - accuracy: 1.0000 - val_loss: 0.2353 - val_accuracy: 0.9542
# Epoch 41/70
# 30/30 [==============================] - 0s 6ms/step - loss: 0.0184 - accuracy: 0.9930 - val_loss: 0.2150 - val_accuracy: 0.9542
# Epoch 42/70
# 30/30 [==============================] - 0s 6ms/step - loss: 8.3172e-04 - accuracy: 0.9999 - val_loss: 0.4431 - val_accuracy: 0.9250
# Epoch 43/70
# 30/30 [==============================] - 0s 6ms/step - loss: 0.0134 - accuracy: 0.9919 - val_loss: 0.2243 - val_accuracy: 0.9542
# Epoch 44/70
# 30/30 [==============================] - 0s 6ms/step - loss: 3.8203e-04 - accuracy: 1.0000 - val_loss: 0.2172 - val_accuracy: 0.9625
# Epoch 45/70
# 30/30 [==============================] - 0s 6ms/step - loss: 0.0037 - accuracy: 0.9990 - val_loss: 0.2134 - val_accuracy: 0.9625
# Epoch 46/70
# 30/30 [==============================] - 0s 6ms/step - loss: 5.3132e-04 - accuracy: 1.0000 - val_loss: 0.2188 - val_accuracy: 0.9625
# Epoch 47/70
# 30/30 [==============================] - 0s 6ms/step - loss: 0.0013 - accuracy: 0.9995 - val_loss: 0.2384 - val_accuracy: 0.9750
# Epoch 48/70
# 30/30 [==============================] - 0s 5ms/step - loss: 8.2626e-04 - accuracy: 1.0000 - val_loss: 0.2355 - val_accuracy: 0.9583
# Epoch 49/70
# 30/30 [==============================] - 0s 5ms/step - loss: 2.4620e-04 - accuracy: 1.0000 - val_loss: 0.2511 - val_accuracy: 0.9583
# Epoch 50/70
# 30/30 [==============================] - 0s 6ms/step - loss: 0.0032 - accuracy: 0.9990 - val_loss: 0.2677 - val_accuracy: 0.9583
# Epoch 51/70
# 30/30 [==============================] - 0s 6ms/step - loss: 4.2723e-04 - accuracy: 1.0000 - val_loss: 0.2625 - val_accuracy: 0.9583
# Epoch 52/70
# 30/30 [==============================] - 0s 6ms/step - loss: 1.6736e-04 - accuracy: 1.0000 - val_loss: 0.2688 - val_accuracy: 0.9583
# Epoch 53/70
# 30/30 [==============================] - 0s 6ms/step - loss: 7.1514e-04 - accuracy: 0.9997 - val_loss: 0.2558 - val_accuracy: 0.9667
# Epoch 54/70
# 30/30 [==============================] - 0s 6ms/step - loss: 3.3575e-04 - accuracy: 1.0000 - val_loss: 0.2619 - val_accuracy: 0.9583
# Epoch 55/70
# 30/30 [==============================] - 0s 6ms/step - loss: 1.5583e-04 - accuracy: 1.0000 - val_loss: 0.2609 - val_accuracy: 0.9583
# Epoch 56/70
# 30/30 [==============================] - 0s 6ms/step - loss: 0.0108 - accuracy: 0.9971 - val_loss: 0.2543 - val_accuracy: 0.9583
# Epoch 57/70
# 30/30 [==============================] - 0s 6ms/step - loss: 1.1508e-04 - accuracy: 1.0000 - val_loss: 0.2585 - val_accuracy: 0.9583
# Epoch 58/70
# 30/30 [==============================] - 0s 5ms/step - loss: 6.4031e-05 - accuracy: 1.0000 - val_loss: 0.2653 - val_accuracy: 0.9583
# Epoch 59/70
# 30/30 [==============================] - 0s 5ms/step - loss: 6.4580e-05 - accuracy: 1.0000 - val_loss: 0.2629 - val_accuracy: 0.9625
# Epoch 60/70
# 30/30 [==============================] - 0s 6ms/step - loss: 0.0120 - accuracy: 0.9952 - val_loss: 0.2613 - val_accuracy: 0.9583
# Epoch 61/70
# 30/30 [==============================] - 0s 5ms/step - loss: 8.7960e-05 - accuracy: 1.0000 - val_loss: 0.2640 - val_accuracy: 0.9583
# Epoch 62/70
# 30/30 [==============================] - 0s 6ms/step - loss: 6.4641e-05 - accuracy: 1.0000 - val_loss: 0.2625 - val_accuracy: 0.9583
# Epoch 63/70
# 30/30 [==============================] - 0s 5ms/step - loss: 0.0036 - accuracy: 0.9992 - val_loss: 0.2871 - val_accuracy: 0.9500
# Epoch 64/70
# 30/30 [==============================] - 0s 5ms/step - loss: 1.0480e-04 - accuracy: 1.0000 - val_loss: 0.2613 - val_accuracy: 0.9583
# Epoch 65/70
# 30/30 [==============================] - 0s 6ms/step - loss: 3.8630e-05 - accuracy: 1.0000 - val_loss: 0.2676 - val_accuracy: 0.9542
# Epoch 66/70
# 30/30 [==============================] - 0s 6ms/step - loss: 2.9791e-05 - accuracy: 1.0000 - val_loss: 0.2930 - val_accuracy: 0.9542
# Epoch 67/70
# 30/30 [==============================] - 0s 6ms/step - loss: 0.0085 - accuracy: 0.9980 - val_loss: 0.2656 - val_accuracy: 0.9625
# Epoch 68/70
# 30/30 [==============================] - 0s 6ms/step - loss: 2.6239e-05 - accuracy: 1.0000 - val_loss: 0.2670 - val_accuracy: 0.9583
# Epoch 69/70
# 30/30 [==============================] - 0s 6ms/step - loss: 2.3153e-05 - accuracy: 1.0000 - val_loss: 0.2725 - val_accuracy: 0.9542
# Epoch 70/70
# 30/30 [==============================] - 0s 6ms/step - loss: 2.2381e-05 - accuracy: 1.0000 - val_loss: 0.2818 - val_accuracy: 0.9542

# %% [markdown]
# #Advanced Challenge: Implementing a Famous Architecture for Cats vs. Dogs
#
# Having trouble designing an effective architecture? Try implementing a version of AlexNet, one of the most famous CNNs for image convolution ever. You can find this image and other useful information on this network [here](https://towardsdatascience.com/the-w3h-of-alexnet-vggnet-resnet-and-inception-7baaaecccc96).
#
# ![](https://lh4.googleusercontent.com/gFAxn9Z-Y1lgkNy2GfsqjXy1DvSuYF8rvP3CslRvmuoP5SUaJMrEOr24YShU_LwalLpYNJFwpJgcDh9whk9XrMOGQ1ADQ9FY_0saicCVH0jsNPDKOYBcTG4YhbqpbPolW4hZSdUsDQ)
#
# How do we read this diagram?
#
# On the left side, we start with images of dimension 227x227x3 (RGB). We apply a filter composed of 96 kernels of size 11x11, with stride size 4. We end up with data of dimension 55x55x96. We pass through multiple layers of convolution and max pooling as shown, before ending with three dense (fully connected) layers.
#
# Not shown: each layer uses ReLU activation, and we include dropout before the first two dense layers. Make sure to include those!
#
# You'll want to adjust some of these dimensions, for a few reasons: we're starting with 150x150 rather than 227x227 images, ending with 2 labels rather than 1000, and have limited data and memory. Use your knowledge of convolution arithmetic (see CNN slides) and the [Keras documentation](https://www.tensorflow.org/api_docs/python/tf/keras/layers/Conv2D) to change the stride, kernel, and/or padding.
#
# Use model.summary() to understand the dimensions of your data at each step. To speed things up as you're building, you can set the number of epochs to 1.

# %%
model = Sequential()
#TODO: Your code to run, train, and test AlexNet here:

model.add(Conv2D(96, 11, strides = 3))
model.add(Activation('relu'))

model.add(Conv2D(256, 5))
model.add(Activation('relu'))

model.add(MaxPooling2D(2))
model.add(Activation('relu'))

model.add(Conv2D(384, 3, padding = 'same'))
model.add(Activation('relu'))

model.add(MaxPooling2D(2))
model.add(Activation('relu'))

model.add(Conv2D(384, 3, padding = 'same'))
model.add(Activation('relu'))

model.add(Conv2D(256, 3, padding = 'same'))
model.add(Activation('relu'))

model.add(MaxPooling2D(2))
model.add(Activation('relu'))

model.add(Flatten())

model.add(Dropout(0.5))
model.add(Dense(4096))
model.add(Activation('relu'))

model.add(Dropout(0.5))
model.add(Dense(128))
model.add(Activation('relu'))

model.add(Dense(2))
model.add(Activation('softmax'))

# initiate RMSprop optimizer
opt = keras.optimizers.RMSprop(lr=0.0001, decay=1e-6)

# Let's train the model using RMSprop
model.compile(loss='categorical_crossentropy',
              optimizer=opt,
              metrics=['accuracy'])

# Train the CNN and plot accuracy.
# Substituted new dataset names; to_categorical converts to one-hot, as ValueError suggests 
history = model.fit(cd_train_inputs, keras.utils.to_categorical(cd_train_labels), \
                    validation_data=(cd_test_inputs, keras.utils.to_categorical(cd_test_labels)), \
                    epochs=10) 
plot_acc(history)

print (model.summary())
# Out:
# Epoch 1/10
# 63/63 [==============================] - 6s 68ms/step - loss: 7.0364 - accuracy: 0.4956 - val_loss: 0.6914 - val_accuracy: 0.5330
# Epoch 2/10
# 63/63 [==============================] - 4s 59ms/step - loss: 0.7575 - accuracy: 0.5070 - val_loss: 0.6854 - val_accuracy: 0.5400
# Epoch 3/10
# 63/63 [==============================] - 4s 59ms/step - loss: 0.7107 - accuracy: 0.5178 - val_loss: 0.6920 - val_accuracy: 0.5310
# Epoch 4/10
# 63/63 [==============================] - 4s 59ms/step - loss: 0.7077 - accuracy: 0.5001 - val_loss: 0.6901 - val_accuracy: 0.5000
# Epoch 5/10
# 63/63 [==============================] - 4s 59ms/step - loss: 0.7026 - accuracy: 0.5038 - val_loss: 0.6841 - val_accuracy: 0.5720
# Epoch 6/10
# 63/63 [==============================] - 4s 60ms/step - loss: 0.6942 - accuracy: 0.5306 - val_loss: 0.7309 - val_accuracy: 0.5100
# Epoch 7/10
# 63/63 [==============================] - 4s 59ms/step - loss: 0.6996 - accuracy: 0.5615 - val_loss: 0.6521 - val_accuracy: 0.6190
# Epoch 8/10
# 63/63 [==============================] - 4s 60ms/step - loss: 0.6505 - accuracy: 0.6350 - val_loss: 0.6485 - val_accuracy: 0.6070
# Epoch 9/10
# 63/63 [==============================] - 4s 60ms/step - loss: 0.6296 - accuracy: 0.6378 - val_loss: 0.6634 - val_accuracy: 0.6290
# Epoch 10/10
# 63/63 [==============================] - 4s 60ms/step - loss: 0.5946 - accuracy: 0.6825 - val_loss: 0.6635 - val_accuracy: 0.6030
# Model: "sequential_5"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_17 (Conv2D)           (None, 47, 47, 96)        34944
# _________________________________________________________________
# activation_23 (Activation)   (None, 47, 47, 96)        0
# _________________________________________________________________
# conv2d_18 (Conv2D)           (None, 43, 43, 256)       614656
# _________________________________________________________________
# activation_24 (Activation)   (None, 43, 43, 256)       0
# _________________________________________________________________
# max_pooling2d_8 (MaxPooling2 (None, 21, 21, 256)       0
# _________________________________________________________________
# activation_25 (Activation)   (None, 21, 21, 256)       0
# _________________________________________________________________
# conv2d_19 (Conv2D)           (None, 21, 21, 384)       885120
# _________________________________________________________________
# activation_26 (Activation)   (None, 21, 21, 384)       0
# _________________________________________________________________
# max_pooling2d_9 (MaxPooling2 (None, 10, 10, 384)       0
# _________________________________________________________________
# activation_27 (Activation)   (None, 10, 10, 384)       0
# _________________________________________________________________
# conv2d_20 (Conv2D)           (None, 10, 10, 384)       1327488
# _________________________________________________________________
# activation_28 (Activation)   (None, 10, 10, 384)       0
# _________________________________________________________________
# conv2d_21 (Conv2D)           (None, 10, 10, 256)       884992
# _________________________________________________________________
# activation_29 (Activation)   (None, 10, 10, 256)       0
# _________________________________________________________________
# max_pooling2d_10 (MaxPooling (None, 5, 5, 256)         0
# _________________________________________________________________
# activation_30 (Activation)   (None, 5, 5, 256)         0
# _________________________________________________________________
# flatten_3 (Flatten)          (None, 6400)              0
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 6400)              0
# _________________________________________________________________
# dense_11 (Dense)             (None, 4096)              26218496
# _________________________________________________________________
# activation_31 (Activation)   (None, 4096)              0
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 4096)              0
# _________________________________________________________________
# dense_12 (Dense)             (None, 128)               524416
# _________________________________________________________________
# activation_32 (Activation)   (None, 128)               0
# _________________________________________________________________
# dense_13 (Dense)             (None, 2)                 258
# _________________________________________________________________
# activation_33 (Activation)   (None, 2)                 0
# =================================================================
# Total params: 30,490,370
# Trainable params: 30,490,370
# Non-trainable params: 0
# _________________________________________________________________
# None

# %% [markdown]
# You might find that even AlexNet isn't working that well for you!
#
# This is because having a good architecture is only half the battle: AlexNet is a complex model designed to learn from millions of images. We're using a small dataset of only 2000 training images, so it's not surprising that our results aren't great. Our model is overfitting: essentially memorizing the few training images, rather than really learning the difference between a cat and a dog. (The advantage is that our model trains quickly.)
#
# To get really good performance, we need more data. If we can't find more, we could use *data augmentation*: inventing new training data by transforming our existing images. You can read more about it at https://blog.keras.io/building-powerful-image-classification-models-using-very-little-data.html.

# %% [markdown]
# ![](https://images.pexels.com/photos/316/black-and-white-animal-dog-pet.jpg?auto=compress&cs=tinysrgb&dpr=2&h=650&w=940)
